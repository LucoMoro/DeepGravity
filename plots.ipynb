# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\luca\anaconda3\envs\condaenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import zipfile
import json

country = 'new_york'
main_color = 'red'
models = ['DG', 'G', 'MFG', 'NG'] 
rounds = ['0']

# %% [markdown]
# # Standard Plots

# %%
dfs = []
for r in rounds:
    for model in models:
        filename = 'tile2cpc_' + model + '_' + country + '_' + r + '.csv'
        df = pd.read_csv('../results/'+filename)
        df.set_index('tile', inplace=True)
        df.fillna(0, inplace=True)
        df.rename(columns={'cpc': r + '_' + model}, inplace=True)
        dfs.append(df)
    
df = dfs[0]
    
for d in dfs[1:]:
    df = df.join(d)

archive = zipfile.ZipFile('C:/Users/Luca/Desktop/programma_tesi/DeepGravity/deepgravity\data/'+ country + '/tileid2oa2handmade_features.zip', 'r')
with archive.open('tileid2oa2handmade_features.json') as f:
    tileid2oa2features2vals = json.load(f)
    
df.reset_index(inplace=True)
df = df[df['tile'] != 0]
areas = list(df['tile'].unique())
tile_sizes = []
for area in areas:
    tile_sizes.append(len(tileid2oa2features2vals[str(area)].keys()))

# %%
df['n_oas'] = tile_sizes

# %%
if country == 'new_york' or country == 'ny10' or country == 'socal':
    #df = df[df.n_oas >= 3]
    duplicates_value="raise"
    df['rank_oa'] = df['n_oas'].rank(method='first')
    deciles_n_oas = pd.qcut(df['rank_oa'], q=10, labels=False, duplicates=duplicates_value)
    print(duplicates_value)
else:
    deciles_n_oas = pd.qcut(df['n_oas'], q=10, labels=False)
df['decile_n_oas'] = deciles_n_oas

df['DG'] = df[[x + '_DG' for x in rounds]].mean(axis=1)
df['G'] = df[[x + '_G' for x in rounds]].mean(axis=1)
df['NG'] = df[[x + '_NG' for x in rounds]].mean(axis=1)
df['MFG'] = df[[x + '_MFG' for x in rounds]].mean(axis=1)
#df['DGsum'] = df[[x + '_DGsum' for x in rounds]].mean(axis=1)

df.rename(columns = {'DG': 'deep', 'G': 'original_p', 'MFG': 'original', 'NG': 'deep_p'}, inplace=True)
df = df.sort_values(by='decile_n_oas')
# Out:
# raise

# %%
country_to_string = {
    'new_york': 'New York'
}

country_to_subid = {
    'new_york': ['a)', 'b)']
}

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharex=True)

st = fig.suptitle(country_to_string[country], fontsize=30)

avg_originals, avg_deeps, avg_originals_p, avg_deeps_p, avg_dg_sums = [], [], [], [], []
std_originals, std_deeps, std_originals_p, std_deeps_p, std_dg_sums = [], [], [], [], []

for decile in df.decile_n_oas.unique():
    df_temp = df[df.decile_n_oas == decile]

    avg_deep = df_temp.deep.mean()
    avg_original_p = df_temp.original_p.mean()
    avg_deep_p = df_temp.deep_p.mean()
    avg_original = df_temp.original.mean()

    avg_deeps.append(avg_deep)
    avg_originals_p.append(avg_original_p)
    avg_deeps_p.append(avg_deep_p)
    avg_originals.append(avg_original)

    std_deep = df_temp.deep.std()
    std_original_p = df_temp.original_p.std()
    std_deep_p = df_temp.deep_p.std()
    std_original = df_temp.original.std()

    std_deeps.append(std_deep)
    std_originals_p.append(std_original_p)
    std_deeps_p.append(std_deep_p)
    std_originals.append(std_original)

    relative_improve_original_p_deep = []
    relative_improve_original_p_deep_p = []
    relative_improve_original_p_original = []

for a, b in zip(avg_originals_p, avg_deeps):
    relative_improve_original_p_deep.append(((b - a) / a)*100)

for a, b in zip(avg_originals_p, avg_deeps_p):
    relative_improve_original_p_deep_p.append(((b - a) / a)*100)

for a, b in zip(avg_originals_p, avg_originals):
    relative_improve_original_p_original.append(((b - a) / a)*100)

#print(len(avg_deeps))
#print(len(avg_deeps_p)
#print(avg_originals_p)

# decile plots
ax = axes[0]

avg_deeps_2 = []
for i in range(len(avg_deeps)):
    avg_deeps_2.append(avg_deeps[i])

avg_deeps_p_2 = []
for i in range(len(avg_deeps_p)):
    avg_deeps_p_2.append(avg_deeps_p[i])

avg_originals_p_2 = []
for i in range(len(avg_originals_p)):
    avg_originals_p_2.append(avg_originals_p[i])

avg_originals_2 = []
for i in range(len(avg_originals)):
    avg_originals_2.append(avg_originals[i])


ax.errorbar(range(10), avg_deeps_2, marker='o',
          color=main_color, label='DG', linewidth=3, markersize=10)

ax.errorbar(range(10), avg_deeps_p_2, marker='v',
          color='lightgrey', label='NG', linewidth=2, markersize=10)  

ax.errorbar(range(10), avg_originals_p_2,
          color='black', label='G', linestyle='--', linewidth=3)  


ax.errorbar(range(10), avg_originals_2, marker='s',
          color='darkgrey', linewidth=2, 
          label='MFG', markersize=8)
          
    #modificare variabili yerr=std_4nomi

ax.set_ylabel('Average CPC', fontsize=25)
ax.set_xlabel('Decile population', fontsize=25)
ax.set_xticks(range(10))
ax.set_xticklabels(range(1, 11))
ax.set_ylim(0,1)
ax.tick_params(labelsize=20)
ax.grid(alpha=0.2)
ax.set_title(country_to_subid[country][0], fontsize=30)
# FUNZIONANTE 
#ax.set_title(country_to_subid, fontsize=30)
ax.legend(fontsize=20, loc=1)

# relative improvement plot

ax = axes[1]

ax.plot(range(len(relative_improve_original_p_deep)), relative_improve_original_p_deep, color=main_color, linewidth=3, 
      marker='o', markersize=10)

ax.plot(range(len(relative_improve_original_p_deep_p)), relative_improve_original_p_deep_p, color='lightgrey', linewidth=2, 
      marker='v', markersize=8)

ax.plot(range(len(relative_improve_original_p_original)), relative_improve_original_p_original, color='darkgrey', linewidth=2, 
      marker='s', markersize=10)

ax.set_ylabel('Relative improvement (%)', fontsize=25)
ax.set_xlabel('Decile population', fontsize=25)
ax.set_ylim(0,max(relative_improve_original_p_deep)+max(relative_improve_original_p_deep)*0.1)
ax.tick_params(labelsize=20)
ax.set_title(country_to_subid[country][1], fontsize=30)
ax.grid(alpha=0.2)



plt.subplots_adjust(wspace=0.3)
#fig.suptitle(country2long_name[country], fontsize=20)
plt.tight_layout()
plt.savefig('../plots/average_cpc_'+country+'.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Luca\Desktop\programma_tesi\DeepGravity\plots.ipynb Cella 8 in <cell line: 121>()
#     <a href='vscode-notebook-cell:/c%3A/Users/Luca/Desktop/programma_tesi/DeepGravity/plots.ipynb#X10sZmlsZQ%3D%3D?line=118'>119</a> #fig.suptitle(country2long_name[country], fontsize=20)
#     <a href='vscode-notebook-cell:/c%3A/Users/Luca/Desktop/programma_tesi/DeepGravity/plots.ipynb#X10sZmlsZQ%3D%3D?line=119'>120</a> plt.tight_layout()
# --> <a href='vscode-notebook-cell:/c%3A/Users/Luca/Desktop/programma_tesi/DeepGravity/plots.ipynb#X10sZmlsZQ%3D%3D?line=120'>121</a> plt.savefig('../plots/average_cpc_'+country+'.pdf')
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File c:\Users\Luca\anaconda3\envs\condaenv\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../plots/average_cpc_new_york.pdf'

# %%
avg_originals_p


#ORIGINALE
#avg_originals_p_2 = []
#for i in range(len(avg_originals_p)):
   # avg_originals_p_2.append(avg_originals_p[i][0])

#avg_originals_p_2
# Out:
# [0.2672165294409159,
#  0.4461112956288591,
#  0.3582176465017411,
#  0.3789005143521148,
#  0.4177798779557374,
#  0.36771139359604427,
#  0.4326279272005919,
#  0.4363499730232043,
#  0.4764225519120734,
#  0.437857725723296]
